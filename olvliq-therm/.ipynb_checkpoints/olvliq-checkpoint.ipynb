# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


def read_data(filename):
    df = pd.read_csv(filename, encoding='utf-8', sep=',')
    return df

# composition is cation fraction
def calctherm():
    d_mg = 0.33
    c_nm = mg_liq + ferrous_liq + ca_liq + mn_liq
    c_si = si_liq
    nf = 3.5 * np.log( 1 - al_liq ) + 7 * np.log( 1 - ti_liq )
    tempc = ( 15294.6 + 1318.8 * pressure + 2.484 * pressure**2 ) \
    / ( 8.048 + 2.8532 * np.log(d_mg) + 2.097 * np.log(1.5 * c_nm) + 2.575 * np.log(3 * c_sio2) \
    - 1.41 * nf + 0.222 * water + 0.5 * pressure )
